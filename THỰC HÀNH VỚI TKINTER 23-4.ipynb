# %%
from tkinter import *

windows = Tk()
windows.title("Simple Calculator")
windows.geometry("400x300")
windows.eval('tk::PlaceWindow . center')

result_text = Label(windows, text = 'Result')

number1 = Entry(windows)
number2 = Entry(windows)

def add():
    result = int(number1.get()) + int(number2.get())
    result_text.config(text=result)
def minus():
    result = int(number1.get()) - int(number2.get())
    result_text.config(text=result) 
def multiphy():
    result = int(number1.get()) * int(number2.get())
    result_text.config(text=result)
def divide():
    result = int(number1.get()) / int(number2.get())
    result_text.config(text=result)


add_btn = Button(windows, text=' + ', width=5, command=add)
minus_btn = Button(windows, text=' - ', width=5, command=minus)
multiphy_btn = Button(windows, text=' * ',width=5, command=multiphy)
divide_btn = Button(windows, text=' / ', width=5, command=divide)

number1.pack()
number2.pack()
add_btn.pack()
minus_btn.pack()
multiphy_btn.pack()
divide_btn.pack()
result_text.pack()

windows.mainloop()

# %%
from tkinter import *
windows = Tk()
windows.title("My Intro")
windows.geometry("400x300")
windows.eval('tk::PlaceWindow . center')

introduction_lbl = Label(windows, text = 'My Introduction')
first_name_lbl = Label(windows, text = 'First name')
last_name_lbl = Label(windows, text = 'Last name')

first_name = Entry(windows)
last_name = Entry(windows)

def intro():
    my_intro = "My name is " + first_name.get() + " " + last_name.get()
    introduction_lbl.config(text=my_intro)
    
submit_btn = Button(windows, text = 'Submit', command=intro )

introduction_lbl.grid(column=0, row=0, columnspan=2)
first_name_lbl.grid(column=0, row=1)
last_name_lbl.grid(column=0, row=2)
first_name.grid(column=1, row=1)
last_name.grid(column=1, row=2)
submit_btn.grid(column=1, row=3)

windows.mainloop()

# %%
from tkinter import *
from tkinter import messagebox
windows = Tk()
windows.title("My BMI")
windows.geometry("400x300")
windows.eval('tk::PlaceWindow . center')

BMI_calculator_lbl = Label(windows, text ="BMI Calculator")
weight_lbl = Label(windows, text = "My weight(kg)")
height_lbl = Label(windows, text = "My heigth(m)")

weight_inp = Entry(windows)
height_inp = Entry(windows)

def BMI():
    result_BMI = float(weight_inp.get())/float(height_inp.get())**2
    messagebox.showinfo("BMI result", f"Your BMI is {result_BMI}")

submit_btn = Button(windows, text = 'Submit', command=BMI )

BMI_calculator_lbl.grid(column=0, row=0, columnspan=2)
weight_lbl.grid(column=0, row=1)
height_lbl.grid(column=0, row=2)
weight_inp.grid(column=1, row=1)
height_inp.grid(column=1, row=2)
submit_btn.grid(column=1, row=3)
                                        
windows.mainloop()

# %%
from tkinter import *
from tkinter.ttk import *
import tkinter.ttk as ttk
import tkinter.messagebox as messagebox

def Application():
    window = Tk()
    window.title("My Todolist")
    window.geometry("900x400")
    
    global tree
    global search
    global task, deadline, classify, status
    search = ''
    task =''
    deadline = ''
    classify =''
    status =''
    
    # tạo khung  
    Form0 = Frame(window, width=600, bd=1, relief=SOLID)
    Form0.pack(side=TOP, fill=X)
    
    Form1 = Frame(window, width=350,bg="#15244C")
    Form1.pack(side=LEFT, fill=Y)
     
    Form2 = Frame(window, width=500,bg="#0B4670")
    Form2.pack(side=LEFT, fill=Y)
    
    Form3 = Frame(window, width=600)
    Form3.pack(side=RIGHT)
Application()
if __name__=='__main__':
    mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Input In [2], in <module>
#      30     Form3 = Frame(window, width=600)
#      31     Form3.pack(side=RIGHT)
# ---> 32 Application()
#      33 if __name__=='__main__':
#      34     mainloop()
#
# Input In [2], in Application()
#      18 status =''
#      20 # tạo khung
# ---> 21 Form0 = Frame(window, width=600, bd=1, relief=SOLID)
#      22 Form0.pack(side=TOP, fill=X)
#      24 Form1 = Frame(window, width=350,bg="#15244C")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\tkinter\ttk.py:735, in Frame.__init__(self, master, **kw)
#     724 def __init__(self, master=None, **kw):
#     725     """Construct a Ttk Frame with parent master.
#     726
#     727     STANDARD OPTIONS
#    (...)
#     733         borderwidth, relief, padding, width, height
#     734     """
# --> 735     Widget.__init__(self, master, "ttk::frame", kw)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\tkinter\ttk.py:552, in Widget.__init__(self, master, widgetname, kw)
#     549 if not getattr(master, '_tile_loaded', False):
#     550     # Load tile now, if needed
#     551     _load_tile(master)
# --> 552 tkinter.Widget.__init__(self, master, widgetname, kw=kw)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\tkinter\__init__.py:2601, in BaseWidget.__init__(self, master, widgetName, cnf, kw, extra)
#    2599 for k, v in classes:
#    2600     del cnf[k]
# -> 2601 self.tk.call(
#    2602     (widgetName, self._w) + extra + self._options(cnf))
#    2603 for k, v in classes:
#    2604     k.configure(self, v)
#
# TclError: unknown option "-bd"
