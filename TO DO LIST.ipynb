# %%
from tkinter import *
from tkinter.ttk import *
from tkinter import messagebox



windows = Tk()
windows.title("My Todolist")
windows.geometry("400x300")
windows.eval('tk::PlaceWindow . center')

date_lbl = Label(windows, text="Date")
list_lbl = Label(windows, text="List of tasks")
classify_lbl = Label(windows, text="Classify")
status_lbl = Label(windows, text="Status")
task_lbl = Label(windows, text="Title")
task_detail_lbl = Label(windows, text="Task detail")
result_lbl =Label(windows, text="Result")

date_inp = Entry(windows)
task_inp = Entry(windows)
task_detail_inp = Entry(windows)
result_inp = Entry(windows)
search_inp = Entry(windows)

combo_classify = Combobox(windows)
combo_classify['value'] = ('Work', 'School', 'Personal')
combo_status = Combobox(windows)
combo_status['value'] = ('Todo', 'Doing', 'Done')

listbox_tasks = Listbox(windows, height=3)

def popup_bonus():
    win = Toplevel()
    win.wm_title("Add Task")
    
    

def search_task():
    pass

def add_task():
    task = task_inp.get()
    if task != "":
        listbox_tasks.insert(END, task)
        task_inp.delete(0, END)
    else: 
        messagebox.showwarning("Warning!", message="You must enter a task")
    
def delete_task():
    pass




search_btn = Button(windows, text="Search", command = search_task)
add_btn = Button(windows, text="Add task", command =  add_task)
delete_btn = Button(windows, text="Delete", command = delete_task)


date_lbl.grid(column=0, row=3)
list_lbl.grid(column=0, row=1)
classify_lbl.grid(column=2, row=3)
status_lbl.grid(column=2, row=5)
task_lbl.grid(column=0, row=4)
task_detail_lbl.grid(column=0, row=5)
result_lbl.grid(column=0, row=6)
date_inp.grid(column=1, row=3)
task_inp.grid(column=1, row=4)
task_detail_inp.grid(column=1, row=5)
result_inp.grid(column=1, row=6)
search_inp.grid(column=1, row=0)
search_btn.grid(column=2, row=0)
add_btn.grid(column=1, row=8)
delete_btn.grid(column=2, row=8)
combo_classify.grid(column=2, row=4)
combo_status.grid(column=2, row=6)
listbox_tasks.grid(column=1, row=1)


windows.mainloop()

# %%
#new
from tkinter import ttk
import tkinter as tk
from tkinter import *

windows = tk.Tk()
def popup_bonus():
        global win
        win = tk.Toplevel(windows)
        win.title("Add a new task")
        win.config(background="green")
        
        title_lbl = tk.Label(win, text="Title:")
        brief_description_lbl =tk.Label(win, text='Brief description:')
        deadline_of_task_lbl = tk.Label(win, text='Deadline of task:')
        classify_lbl = tk.Label(win, text='Classify')
        status_lbl = tk.Label(win, text='Status')
        
        title_inp = tk.Entry(win)
        brief_description_inp =tk.Entry(win)
        deadline_of_task_inp = tk.Entry(win)
        
        combo_classify = tk.Combobox(windows)
        combo_classify['value'] = ('Work', 'School', 'Personal')
        combo_status = tk.Combobox(windows)
        combo_status['value'] = ('Todo', 'Doing', 'Done')

        add_btn = tk.Button(win, text='Add', command=insert_data)
        
        title_lbl.grid(column=0,row=0)
        brief_description_lbl.grid(column=0,row=0)
        deadline_of_task_lbl.grid(column=0,row=0)
        classify_lbl.grid(column=0,row=0)
        status_lbl.grid(column=0,row=0)
        title_inp.grid(column=0,row=0)
        brief_description_inp.grid(column=0,row=0)
        deadline_of_task_inp.grid(column=0,row=0)
        combo_classify.grid(column=0,row=0)
        combo_status.grid(column=0,row=0)
        add_btn.grid(column=0,row=0)
        

class MainApp(ttk.Frame):
    def __init__(self, windows):
        
        ttk.Frame.__init__(self, windows)
        self.windows=windows
        self.infomation_of_task()
        
    def search_task():
        pass
    def infomation_of_task(self):
        self.windows.title("My Todolist")
        self.windows.config(background="yellow")
        
        
        self.list_of_tasks_lbl = tk.Label(self.windows, text="List of tasks")
        self.list_of_tasks_lbl.grid(column=3, row=0,columnspan=3)
        self.search_btn = tk.Button(self.windows, text="Search")
        self.search_btn.grid(column=0, row=0)
        self.search_inp = tk.Entry(self.windows)
        self.search_inp.grid(column=1, row=0)
        
        self.add_task_btn = tk.Button(self.windows, text="Add a new task", command=popup_bonus)
        self.add_task_btn.grid(column=0, row=1)
        self.delete_btn = tk.Button(self.windows, text="Delete task")
        self.delete_btn.grid(column=0, row=2)
        
        self.tree = ttk.Treeview(self.windows, columns = ('Deadline','Title', 'Status'))
        self.tree.heading('#0', text='Deadline')
        self.tree.heading('#1', text='Title')
        self.tree.heading('#2', text='Status')
        self.tree.column('#1', stretch=tk.YES)
        self.tree.column('#2', stretch=tk.YES)
        self.tree.column('#0', stretch=tk.YES)
        self.tree.grid(column=3,row=1, columnspan=3, sticky='nsew')
        self.treeview = self.tree
    
    def insert_data(self):
        self.treeview.insert('', 'end', values=(self.deadline_of_task_inp.get(), self.title_inp.get(), self.combo_status.get()))
        
    
def main():
    d=MainApp(windows)
    windows.mainloop()

if __name__=="__main__":
    main()

# %%
try:
    import Tkinter
    import ttk
except ImportError:  # Python 3
    import tkinter as Tkinter
    import tkinter.ttk as ttk

windows = tk.Tk()


class MainApp(Tkinter.Frame):
    def __init__(self, windows):
        
        Tkinter.Frame.__init__(self, windows)
        self.windows=windows
        self.infomation_of_task()
        
       
    
    def infomation_of_task(self):
        self.windows.title("My Todolist")
        self.windows.config(background="#B3D9EA")
        self.windows.geometry('1350x700+0+0')
        
         # các biến 
        self.task_var = StringVar()
        self.deadline_var = StringVar()
        self.classify_var = StringVar()
        self.status_var = StringVar() 
        
        self.title = Tkinter.Label(self.windows, text='My Todolist', font=('Courier new',40, 'bold'), bg='#619196', fg='white')
        self.title.pack(side=TOP, fill=X)
        
        self.info_frame= Tkinter.Frame(self.windows, bd=4, relief=RIDGE, bg='#619196')
        self.info_frame.place(x=20, y=100, width=450, height=500)
        
        self.title_info_lbl= Tkinter.Label(self.info_frame, text='About task', bg='#619196',fg='white', font=('Courier new', 30, 'bold'))
        self.title_info_lbl.grid(row=0, columnspan=2, pady=20)
        
        self.task_lbl=Tkinter.Label(self.info_frame, text='Task', bg='#619196', fg='white', font=('Courier new', 20, 'bold'))
        self.task_lbl.grid(row=1, column=0, pady=10, padx=20, sticky='w')
        
        self.task_ent=Tkinter.Entry(self.info_frame, textvariable=self.task_var,font=('Courier new', 15,'bold'), bd=5, relief=GROOVE)
        self.task_ent.grid(row=1, column=1, pady=10, padx=8, sticky='w')
        
        self.deadline_lbl=Tkinter.Label(self.info_frame, text='Deadline', bg='#619196', fg='white', font=('Courier new', 20, 'bold'))
        self.deadline_lbl.grid(row=2, column=0, pady=10, padx=20, sticky='w')
        
        self.deadline_ent=Tkinter.Entry(self.info_frame, textvariable=self.deadline_var,font=('Courier new', 15,'bold'), bd=5, relief=GROOVE)
        self.deadline_ent.grid(row=2, column=1, pady=10, padx=8, sticky='w')

        self.classify_lbl=Tkinter.Label(self.info_frame, text='Classify', bg='#619196', fg='white', font=('Courier new', 20, 'bold'))
        self.classify_lbl.grid(row=3, column=0, pady=10, padx=20, sticky='w')
        
        self.classify_combo = ttk.Combobox(self.info_frame,textvariable=self.classify_var, font=('Courier new', 13, 'bold'))
        self.classify_combo['values']=('Work', 'School', 'Personal')
        self.classify_combo.grid(row=3, column=1, pady=10, padx=20)
        
        self.status_lbl=Tkinter.Label(self.info_frame, text='Status', bg='#619196', fg='white', font=('Courier new', 20, 'bold'))
        self.status_lbl.grid(row=4, column=0, pady=10, padx=20, sticky='w')
        
        self.status_combo = ttk.Combobox(self.info_frame,textvariable=self.status_var, font=('Courier new', 13, 'bold'))
        self.status_combo['values']=('Todo', 'Doing', 'Done')
        self.status_combo.grid(row=4, column=1, pady=10, padx=20)
        
        self.button_frame= Tkinter.Frame(self.info_frame, bd=4, relief=RIDGE, bg='#B3D9EA')
        self.button_frame.place(x=10, y=400, width=430)
        
        self.addbtn=Button(self.button_frame, text='Add', width=10, command=add_task)
        self.addbtn.grid(row=0, column=0, padx=10, pady=10)
        
        self.updatebtn=Button(self.button_frame, text='Update', width=10)
        self.updatebtn.grid(row=0, column=1, padx=10, pady=10)
        
        self.deletebtn=Button(self.button_frame, text='Delete',width=10)
        self.deletebtn.grid(row=0, column=2, padx=10, pady=10)
        
        self.clearbtn=Button(self.button_frame, text='Clear', width=10)
        self.clearbtn.grid(row=0, column=3, padx=10, pady=10)
        #show task
        self.show_frame= Tkinter.Frame(self.windows, bd=4, relief=RIDGE, bg='#619196')
        self.show_frame.place(x=500, y=100, width=800, height=580)
        
        self.search_lbl = Tkinter.Label(self.show_frame, text='Search by', bg= '#619196', fg='white', font=('Courier new', 15, 'bold'))
        self.search_lbl.grid(row=0, column=0, pady=10, padx=20, sticky='w')
        
        self.search_combo = ttk.Combobox(self.show_frame, font=('Courier new', 13, 'bold'))
        self.search_combo['values']=('Task', 'Deadline', 'Status')
        self.search_combo.grid(row=0, column=1, pady=10, padx=5)
        
        self.search_ent = Tkinter.Entry(self.show_frame, width=20, font=('Courier new',10, 'bold'), bd=5, relief=GROOVE)
        self.search_ent.grid(row=0, column=2, pady=10, padx=20, sticky='w')
        
        self.searchbtn= Tkinter.Button(self.show_frame, text='Search', width=10, pady=5)
        self.searchbtn.grid(row=0, column=3, padx=10, pady=10)
        
      
        
        #show data
        self.table_frame=Tkinter.Frame(self.show_frame, bd=4, relief=RIDGE, bg='#619196')
        self.table_frame.place(x=10, y=60, width=760, height=500)
        
        self.scroll_x= Tkinter.Scrollbar(self.table_frame, orient=HORIZONTAL)
        self.scroll_y= Tkinter.Scrollbar(self.table_frame, orient=VERTICAL)
        self.task_table= ttk.Treeview(self.table_frame, columns=('Task', 'Deadline', 'Classify', 'Status'), xscrollcommand=self.scroll_x.set, yscrollcommand=self.scroll_y.set)
        self.scroll_x.pack(side=BOTTOM, fill =X)
        self.scroll_y.pack(side=RIGHT, fill =Y)
        self.scroll_x.config(command=self.task_table.xview)
        self.scroll_y.config(command=self.task_table.yview)
        self.task_table.heading('Task', text='Task')
        self.task_table.heading('Deadline', text='Deadline')
        self.task_table.heading('Classify', text='Classify')
        self.task_table.heading('Status', text='Status')
        self.task_table['show']='headings'
        self.task_table.column('Task', width=150)
        self.task_table.column('Deadline', width=100)
        self.task_table.column('Classify', width=100)
        self.task_table.column('Status', width=100)
        self.task_table.pack(fill=BOTH, expand=1)
        
    
    # CLEAR TASK
    def clear_value():
        self.task_ent.delete(0, END)
        self.deadline_ent.delete(0,END)
        self.status_combo.delete(0, END)
        self.classify_combo.delete(0,END)
        
    # ADD TASK
    list_info = []
    def add_task():
        global list_info 
        self.info = (self.task_ent.get(), self.deadline_ent.get(), self.classify_combo.get(), self.status_combo.get())
        self.list_info.append(self.info)
        for self.info in self.list_info:
            self.task_table.insert('',Tkinter.END, values = self.info)
        clear_entry_value()
    def search_task():
        for self.info in self.list_info:
            
        
        
        
        
def main():
    d=MainApp(windows)
    windows.mainloop()

if __name__=="__main__":
    main()

# %%
    
    def add_data(self):
        self.treeview.insert('', 'end', values=(self.deadline_of_task_inp.get(), self.title_inp.get(), self.combo_status.get()))
        
    def delete_task():
        pass    
    def search_task():
        pass
